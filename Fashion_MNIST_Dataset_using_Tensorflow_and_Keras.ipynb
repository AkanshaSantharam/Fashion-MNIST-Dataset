# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import tensorflow as tf

# %%
data=tf.keras.datasets.fashion_mnist

# %%
(x_train,y_train), (x_test,y_test)=data.load_data()

# %%
plt.imshow(x_train[0],cmap=plt.cm.binary)
plt.show()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
y_train
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
plt.figure(figsize=(15,25))
for num in range(20):
  plt.subplot(5,4,num+1)
  plt.imshow(x_train[num],cmap=plt.cm.binary)
  plt.xlabel(class_names[y_train[num]])
plt.show()

# %%
model=tf.keras.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)),
                           tf.keras.layers.Dense(200,activation='relu'),
                           tf.keras.layers.Dense(10,activation='softmax')])

# %%
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 200)               157000
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2010
# =================================================================
# Total params: 159,010
# Trainable params: 159,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.9615 - accuracy: 0.7229
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6186 - accuracy: 0.7956
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5531 - accuracy: 0.8109
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5141 - accuracy: 0.8255
# Epoch 5/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5003 - accuracy: 0.8335
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4911 - accuracy: 0.8404
# Epoch 7/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4730 - accuracy: 0.8444
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4809 - accuracy: 0.8433
# Epoch 9/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4757 - accuracy: 0.8419
# Epoch 10/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4568 - accuracy: 0.8475

# %%
model.evaluate(x_test,y_test,verbose=1)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.5492 - accuracy: 0.8305
# [0.549224853515625, 0.8305000066757202]

# %%
plt.imshow(x_test[3],cmap=plt.cm.binary)
plt.xlabel(class_names[y_test[3]])
plt.show()

# %%
img=x_test[3].reshape(1,28,28)

# %%
pred=model.predict(img)
print(pred)
# Out:
# [[4.2983014e-18 1.0000000e+00 0.0000000e+00 3.5714886e-17 3.1737615e-25
#   0.0000000e+00 1.0004286e-20 0.0000000e+00 4.7228045e-22 0.0000000e+00]]

# %%
np.argmax(pred)
# Out:
# 1

# %%
class_names[np.argmax(pred)]
# Out:
# 'Trouser'
